# %%
# !pip install pandas scikit-learn matplotlib
# !pip install gdown

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load the dataset
import gdown
import pandas as pd

file_id = 'https://drive.google.com/file/d/1hGJnuh9PDSXAsNJeT-eKLMegkHuo5Dx4/view?usp=sharing'

# Download the file
url = f'https://drive.google.com/uc?id=1hGJnuh9PDSXAsNJeT-eKLMegkHuo5Dx4'
output = 'train.csv'
gdown.download(url, output, quiet=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(output)

# Select relevant features (square footage, bedrooms, bathrooms) and the target variable (SalePrice)
features = df[['GrLivArea', 'BedroomAbvGr', 'FullBath']]
target = df['SalePrice']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Visualize the predictions vs actual values
plt.scatter(X_test['GrLivArea'], y_test, color='black', label='Actual Prices')
plt.scatter(X_test['GrLivArea'], y_pred, color='blue', label='Predicted Prices')
plt.xlabel('Square Footage (GrLivArea)')
plt.ylabel('Sale Price')
plt.title('Linear Regression: Predicted vs Actual Prices')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hGJnuh9PDSXAsNJeT-eKLMegkHuo5Dx4
# To: /content/train.csv
# 100%|██████████| 461k/461k [00:00<00:00, 90.8MB/s]
# Mean Squared Error: 2806426667.247853
